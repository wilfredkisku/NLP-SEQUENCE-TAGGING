# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import csv
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt


class samsungNLPchallange():
    def __init__(self):
        
        self.file_path_train = '/content/drive/MyDrive/models/prometeo/train/'
        self.file_path_test = '/content/drive/MyDrive/models/prometeo/'
        self.train_x_y = []
        self.train_x_y_f = []

        self.classes = []
        self.words = []

        return None

    def prepareTestData(self):
        f = open(self.file_path_test+'test_public.csv')
        csvreader = csv.reader(f)
        header = []
        rows = []
        tokens = []

        header = next(csvreader)
        for row in csvreader:
            rows.append(row)

        for sen in rows:
            for w in sen[1].split():
                tokens.append(w)

        print(len(tokens))
        return None
    
    def prepareTrainData(self):
        dir_list = os.listdir(self.file_path_train)
        dir_list = sorted(dir_list)
        
        line_f = []
        for i in range(len(dir_list)):
            with open(self.file_path_train+dir_list[i], 'r') as f:
                line = ''
                #line_f = []
                while True:
                    line = f.readline()
                    line_s = line.split('\t')
                    line_t = [] 
                    for l in line_s:
                        line_t.append(l.split())
                    line_f.append(line_t)  
                    if line == '':
                        break
            
                line_f = line_f[:len(line_f)-1]

            f.close()

        self.train_x_y = line_f
        return line_f

    def prepareLabels(self):
        
        unique = []

        for val in self.train_x_y:
            for v in val[1]:
                if v not in unique:
                    unique.append(v)
        
        unique = sorted(unique)
        
        self.classes = unique

        return unique

    def prepareWordBag(self):
        
        unique = []

        for val in self.train_x_y:
            for v in val[0]:
                if v not in unique:
                    unique.append(v)
        unique = sorted(unique)
        self.words = unique
        return unique

    def mapping(self):
        
        t_train_x_y_f = []
        
        w_n = len(self.words)
        c_n = len(self.classes)
        
        for x in self.train_x_y:
            
            w_index = []
            
            for xx in x[0]:
                w_index.append(self.words.index(xx))
            
            c_index = []
            
            for yy in x[1]:
                c_index.append(self.classes.index(yy))
            
            t_train_x_y_f.append(torch.LongTensor([w_index,c_index]))
        
        self.train_x_y_f = t_train_x_y_f

        return t_train_x_y_f

    def mappingTest(self,test):

        t_test_x_y_f = []
        count = 0
        for x in test:

            w_index = []

            for xx in x:
                try:
                    w_index.append(self.words.index(xx))
                except:
                    w_index.append(32)
                    count += 1

            t_test_x_y_f.append(torch.LongTensor(w_index))
        #print(count)
        return t_test_x_y_f


class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()

        self.hidden_dim = hidden_dim
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)
        self.hidden = self.init_hidden()


    def init_hidden(self):
        return (torch.zeros(1, 1, self.hidden_dim),
                torch.zeros(1, 1, self.hidden_dim))

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)

        lstm_out, self.hidden = self.lstm(
            embeds.view(len(sentence), 1, -1), self.hidden)
        
        tag_outputs = self.hidden2tag(lstm_out.view(len(sentence), -1))
        #tag_outputs = self.hidden2tag(tag_outputs_.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_outputs, dim=1)

        return tag_scores

if __name__ == "__main__":

    OBJ     = samsungNLPchallange()
    train   = OBJ.prepareTrainData()
    classes = OBJ.prepareLabels()
    words   = OBJ.prepareWordBag()
    final   = OBJ.mapping()
    #print(len(train))
    #print(classes)
    #print(words)
    #print(final)

# %%
final[0][0]
# Out:
# tensor([ 798, 1145, 1453,  128,  359,  120, 1596,  359,  761,  233])

# %%
# the embedding dimension defines the size of our word vectors
# for our simple vocabulary and training set, we will keep these small
EMBEDDING_DIM = 10
HIDDEN_DIM = 10

# instantiate our model
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(words), len(classes))

# define our loss and optimizer
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.03)

# %%
test_sentence = "The cheese loves the elephant".lower().split()

inputs = final[0][0]
inputs = inputs
tag_scores = model(inputs)
#print(tag_scores)

_, predicted_tags = torch.max(tag_scores, 1)
#print('\n')
print('Predicted tags: \n',predicted_tags)
# Out:
# Predicted tags:
#  tensor([14,  1, 24, 16, 16,  2, 16, 16, 16, 16])

# %%
# normally these epochs take a lot longer 
# but with our toy data (only 3 sentences), we can do many epochs in a short time
n_epochs = 3000

import random

for epoch in range(n_epochs):
    
    epoch_loss = 0.0
    random.shuffle(final)
    # get all sentences and corresponding tags in the training data
    #for sentence, tags in training_data:
    for sentence, tags in final:    
        # zero the gradients
        model.zero_grad()

        # zero the hidden state of the LSTM, this detaches it from its history
        model.hidden = model.init_hidden()

        # prepare the inputs for processing by out network, 
        # turn all sentences and targets into Tensors of numerical indices
        #sentence_in = prepare_sequence(sentence, word2idx)
        #targets = prepare_sequence(tags, tag2idx)

        # forward pass to get tag scores
        tag_scores = model(sentence)

        # compute the loss, and gradients 
        loss = loss_function(tag_scores, tags)
        epoch_loss += loss.item()
        loss.backward()
        
        # update the model parameters with optimizer.step()
        optimizer.step()
        
    # print out avg loss per 20 epochs
    if(epoch%20 == 19):
        print("Epoch: %d, loss: %1.5f" % (epoch+1, epoch_loss/len(final)))
# Out:
# Epoch: 20, loss: 0.44717
# Epoch: 40, loss: 0.38031
# Epoch: 60, loss: 0.32876
# Epoch: 80, loss: 0.28921
# Epoch: 100, loss: 0.26758
# Epoch: 120, loss: 0.23081
# Epoch: 140, loss: 0.21123
# Epoch: 160, loss: 0.19382
# Epoch: 180, loss: 0.19116
# Epoch: 200, loss: 0.19560
# Epoch: 220, loss: 0.16917
# Epoch: 240, loss: 0.14597
# Epoch: 260, loss: 0.14059
# Epoch: 280, loss: 0.13064
# Epoch: 300, loss: 0.12438
# Epoch: 320, loss: 0.12445
# Epoch: 340, loss: 0.11346
# Epoch: 360, loss: 0.34973
# Epoch: 380, loss: 0.15002
# Epoch: 400, loss: 0.13043
# Epoch: 420, loss: 0.12818
# Epoch: 440, loss: 0.11172
# Epoch: 460, loss: 0.10402
# Epoch: 480, loss: 0.10085
# Epoch: 500, loss: 0.09632
# Epoch: 520, loss: 0.09378
# Epoch: 540, loss: 0.09005
# Epoch: 560, loss: 0.11133
# Epoch: 580, loss: 0.08533
# Epoch: 600, loss: 0.08199
# Epoch: 620, loss: 0.14384
# Epoch: 640, loss: 0.08453
# Epoch: 660, loss: 0.08053
# Epoch: 680, loss: 0.09985
# Epoch: 700, loss: 0.07510
# Epoch: 720, loss: 0.07280
# Epoch: 740, loss: 0.09865
# Epoch: 760, loss: 0.07804
# Epoch: 780, loss: 0.07450
# Epoch: 800, loss: 0.07273
# Epoch: 820, loss: 0.06930
# Epoch: 840, loss: 0.06640
# Epoch: 860, loss: 0.06634
# Epoch: 880, loss: 0.06534
# Epoch: 900, loss: 0.06393
# Epoch: 920, loss: 0.08110
# Epoch: 940, loss: 0.08006
# Epoch: 960, loss: 0.06335
# Epoch: 980, loss: 0.07272
# Epoch: 1000, loss: 0.08284
# Epoch: 1020, loss: 0.08157
# Epoch: 1040, loss: 0.06085
# Epoch: 1060, loss: 0.05895
# Epoch: 1080, loss: 0.06534
# Epoch: 1100, loss: 0.05918
# Epoch: 1120, loss: 0.05782
# Epoch: 1140, loss: 0.05947
# Epoch: 1160, loss: 0.06055
# Epoch: 1180, loss: 0.05652
# Epoch: 1200, loss: 0.05550
# Epoch: 1220, loss: 0.05436
# Epoch: 1240, loss: 0.06315
# Epoch: 1260, loss: 0.11861
# Epoch: 1280, loss: 0.07242
# Epoch: 1300, loss: 0.06183
# Epoch: 1320, loss: 0.05918
# Epoch: 1340, loss: 0.05864
# Epoch: 1360, loss: 0.05746
# Epoch: 1380, loss: 0.05643
# Epoch: 1400, loss: 0.05480
# Epoch: 1420, loss: 0.05625
# Epoch: 1440, loss: 0.10061
# Epoch: 1460, loss: 0.07470
# Epoch: 1480, loss: 0.05964
# Epoch: 1500, loss: 0.05646
# Epoch: 1520, loss: 0.05633
# Epoch: 1540, loss: 0.05286
# Epoch: 1560, loss: 0.05164
# Epoch: 1580, loss: 0.08235
# Epoch: 1600, loss: 0.05403
# Epoch: 1620, loss: 0.05234
# Epoch: 1640, loss: 0.05152
# Epoch: 1660, loss: 0.05129
# Epoch: 1680, loss: 0.05450
# Epoch: 1700, loss: 0.05054
# Epoch: 1720, loss: 0.04893
# Epoch: 1740, loss: 0.04838
# Epoch: 1760, loss: 0.06563
# Epoch: 1780, loss: 0.05197
# Epoch: 1800, loss: 0.04979
# Epoch: 1820, loss: 0.04836
# Epoch: 1840, loss: 0.10428
# Epoch: 1860, loss: 0.04974
# Epoch: 1880, loss: 0.04951
# Epoch: 1900, loss: 0.04784
# Epoch: 1920, loss: 0.04688
# Epoch: 1940, loss: 0.04666
# Epoch: 1960, loss: 0.04652
# Epoch: 1980, loss: 0.04800
# Epoch: 2000, loss: 0.04579
# Epoch: 2020, loss: 0.04503
# Epoch: 2040, loss: 0.05643
# Epoch: 2060, loss: 0.05420
# Epoch: 2080, loss: 0.04877
# Epoch: 2100, loss: 0.04654
# Epoch: 2120, loss: 0.04573
# Epoch: 2140, loss: 0.04514
# Epoch: 2160, loss: 0.05588
# Epoch: 2180, loss: 0.04539
# Epoch: 2200, loss: 0.04457
# Epoch: 2220, loss: 0.04797
# Epoch: 2240, loss: 0.04397
# Epoch: 2260, loss: 0.04370
# Epoch: 2280, loss: 0.08274
# Epoch: 2300, loss: 0.05156
# Epoch: 2320, loss: 0.04718
# Epoch: 2340, loss: 0.04592
# Epoch: 2360, loss: 0.04456
# Epoch: 2380, loss: 0.04891
# Epoch: 2400, loss: 0.04520
# Epoch: 2420, loss: 0.04475
# Epoch: 2440, loss: 0.04354
# Epoch: 2460, loss: 0.04359
# Epoch: 2480, loss: 0.04351
# Epoch: 2500, loss: 0.07770
# Epoch: 2520, loss: 0.05391
# Epoch: 2540, loss: 0.04843
# Epoch: 2560, loss: 0.04660
# Epoch: 2580, loss: 0.04516
# Epoch: 2600, loss: 0.04463
# Epoch: 2620, loss: 0.05483
# Epoch: 2640, loss: 0.06094
# Epoch: 2660, loss: 0.05027
# Epoch: 2680, loss: 0.04800
# Epoch: 2700, loss: 0.10649
# Epoch: 2720, loss: 0.05336
# Epoch: 2740, loss: 0.05332
# Epoch: 2760, loss: 0.05775
# Epoch: 2780, loss: 0.04868
# Epoch: 2800, loss: 0.04682
# Epoch: 2820, loss: 0.04567
# Epoch: 2840, loss: 0.04448
# Epoch: 2860, loss: 0.04460
# Epoch: 2880, loss: 0.04499
# Epoch: 2900, loss: 0.04429
# Epoch: 2920, loss: 0.04328
# Epoch: 2940, loss: 0.04312
# Epoch: 2960, loss: 0.04247
# Epoch: 2980, loss: 0.04256
# Epoch: 3000, loss: 0.04190

# %%
final[7][1]
# Out:
# tensor([ 0, 17, 32, 32, 32, 32])

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/models/prometeo/model_LSTM_03.pt')

# %%
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(words), len(classes))

model.load_state_dict(torch.load('/content/drive/MyDrive/models/prometeo/model_LSTM_03.pt'))
# Out:
# <All keys matched successfully>

# %%
file = open('/content/drive/MyDrive/models/prometeo/test_public.csv')
csvreader = csv.reader(file)

header = []
rows = []

header = next(csvreader)
for row in csvreader:
  rows.append(row)

input_text = []

for i in rows:
  input_text.append(i[1].split())

#print(input_text)

test_final = OBJ.mappingTest(input_text)

# %%
input_text
# Out:
# [['sakshi', 'ki', 'landline', 'mein', 'call', 'karo'],
#  ['call', 'karo', 'chacha', 'ko', 'mobile', 'pe'],
#  ['dadaji', 'ke', 'mobile', 'pe', 'call', 'karo'],
#  ['vinuth', 'ko', 'redial', 'karo'],
#  ['mere',
#   'sasurji',
#   'ke',
#   'ghar',
#   'wale',
#   'number',
#   'par',
#   'abhi',
#   'ke',
#   'abhi',
#   'phone',
#   'ghumao'],
#  ['gudiya', 'ki', 'mobile', 'pe', 'dial', 'karo'],
#  ['meri',
#   'baat',
#   'karao',
#   'abhijeet',
#   'se',
#   'sim',
#   '2',
#   'card',
#   'use',
#   'karna'],
#  ['mausa', 'ji', 'ko', 'jaldi', 'se', 'ring', 'back', 'karien'],
#  ['mujhe', 'sim', '2', 'se', 'mom', 'ko', 'call', 'karna', 'hain'],
#  ['mujhe', 'abhi', 'nani', 'se', 'baat', 'karni', 'hain'],
#  ['dadi', 'ke', 'landline', 'number', 'par', 'phone', 'karo'],
#  ['phuphi', 'ji', 'ko', 'call', 'karo'],
#  ['please', 'varun', 'ko', 'phone', 'lagiyen'],
#  ['rasika', 'ke', 'office', 'ke', 'number', 'par', 'call', 'please'],
#  ['mujhe', 'angad', 'se', 'baat', 'karni', 'hai'],
#  ['baat', 'karao', 'zara', 'sabina', 'se'],
#  ['tarun', 'ki', 'durvas', 'yantra', 'mein', 'numbar', 'lagaye'],
#  ['nandoi', 'ji', 'ki', 'number', 'miliyen', 'please'],
#  ['waseem', 'ko', 'call', 'kariye', 'abhi', 'ke', 'abhi'],
#  ['surabhi', 'ki', 'landline', 'mein', 'call', 'back', 'karien'],
#  ['is', 'page', 'ki', 'picture', 'click', 'karo'],
#  ['is', 'page', 'ka', 'screenshot', 'lene', 'me', 'meri', 'help', 'kar', 'do'],
#  ['screenshot', 'lijiye', 'aur', 'gallery', 'mein', 'save', 'kijiye'],
#  ['please', 'capture', 'the', 'screen'],
#  ['ho', 'sake', 'to', 'is', 'page', 'ka', 'ek', 'screen', 'shot', 'le', 'lo'],
#  ['mujhe', 'screenshot', 'chahiye'],
#  ['kripaya', 'screenshot', 'khicho'],
#  ['kripaya', 'screenshot', 'lijiye'],
#  ['kia', 'ye', 'wali', 'screen', 'k', 'chitra', 'khich', 'sakte', 'hain'],
#  ['mere', 'phone', 'ke', 'wallpaper', 'ka', 'screenshot', 'lo'],
#  ['mere', 'phopne', 'ke', 'page', 'ka', 'screenshot', 'lo'],
#  ['screenshot', 'le', 'le'],
#  ['ye', 'phone', 'screen', 'ki', 'picture', 'lekar', 'save', 'karo'],
#  ['kia', 'screenshot', 'save', 'kar', 'sakte', 'hain'],
#  ['screenshot', 'ko', 'lijiye'],
#  ['kripaya',
#   'screenshot',
#   'lene',
#   'k',
#   'baad',
#   'gallery',
#   'mein',
#   'save',
#   'karen'],
#  ['take', 'a', 'picture', 'mere', 'phone', 'ke', 'display', 'page', 'ka'],
#  ['screen', 'ka', 'picture', 'ko', 'khicho'],
#  ['mere',
#   'phone',
#   'pe',
#   'jo',
#   'dikh',
#   'raha',
#   'hai',
#   'uska',
#   'screen',
#   'shot',
#   'lo'],
#  ['screen', 'ki', 'picture', 'save', 'kijiye'],
#  ['wake', 'me', 'up', 'at', '11', 'pm', 'cinema', 'dekhna', 'hai', 'tv', 'pe'],
#  ['please',
#   'tum',
#   'ek',
#   'alarm',
#   'set',
#   'karo',
#   'kal',
#   'subah',
#   '11',
#   'baje',
#   'ka',
#   'recharge',
#   'naam',
#   'se'],
#  ['mujhe', '30', 'minute', 'mein', 'uthao'],
#  ['morning',
#   'alarm',
#   'create',
#   'kar',
#   'do',
#   'at',
#   '6',
#   'in',
#   'the',
#   'morning'],
#  ['saas',
#   'bahu',
#   'serial',
#   'wale',
#   'naam',
#   'se',
#   'ek',
#   'alarm',
#   'banaiye',
#   'har',
#   'guruvaar',
#   'raat',
#   '8',
#   'baje'],
#  ['kal', '5', 'ko', 'tv', 'pe', 'cinema', 'dekhna', 'hain', 'alarm', 'rakho'],
#  ['please',
#   'ek',
#   'alarm',
#   'set',
#   'karke',
#   'do',
#   '3',
#   'baje',
#   'movie',
#   'naam',
#   'se'],
#  ['please',
#   'ek',
#   'alarm',
#   'set',
#   'kar',
#   'do',
#   'zara',
#   'for',
#   '9',
#   'pm',
#   'tomorrow'],
#  ['every',
#   'day',
#   '8',
#   'pm',
#   'alarm',
#   'bajao',
#   'gudiya',
#   'ki',
#   'dawai',
#   'ke',
#   'naam',
#   'se'],
#  ['subah', 'utha', 'dena', 'mujhe', '4', 'baje', 'mandir', 'jana', 'hai'],
#  ['alarm',
#   'sound',
#   'karein',
#   'kal',
#   'subha',
#   '10',
#   'ka',
#   'cookery',
#   'show',
#   'naam',
#   'rakhlo'],
#  ['yoga',
#   'abhyas',
#   'ke',
#   'naam',
#   'se',
#   'har',
#   'tuesday',
#   'aur',
#   'thursday',
#   '5:30',
#   'pm',
#   'ka',
#   'alarm',
#   'set',
#   'karein'],
#  ['mera', 'exam', 'hai', 'kal', 'subah', 'jaldi', 'utha', 'dena', '5', 'baje'],
#  ['alarm', 'lagao', 'agle', 'hafte', 'wednesday', 'ko', '6:16', 'par'],
#  ['dadu',
#   'ka',
#   'physiotherapy',
#   'ke',
#   'name',
#   'se',
#   'har',
#   'saturday',
#   '9',
#   'am',
#   'ki',
#   'alarm',
#   'set',
#   'karein'],
#  ['mujhe',
#   'raat',
#   'ko',
#   'jaldi',
#   'khana',
#   'kha',
#   'lena',
#   'hai',
#   '9',
#   'baje',
#   'dinner',
#   'ka',
#   'alarm',
#   'lagao'],
#  ['cookery',
#   'show',
#   'title',
#   'pe',
#   'ek',
#   'alarm',
#   'lagao',
#   'every',
#   'wednesday',
#   'at',
#   '10',
#   'am'],
#  ['subha', '9', 'baje', 'jaga', 'dena'],
#  ['alarm',
#   'rakhlo',
#   'parso',
#   '11',
#   'baje',
#   'ka',
#   'football',
#   'practice',
#   'ke',
#   'naam',
#   'pe'],
#  ['kal',
#   'subah',
#   '8',
#   'baje',
#   'ka',
#   'alarm',
#   'lagao',
#   'naam',
#   'wake',
#   'up',
#   'rakho'],
#  ['act', 'fibernet', 'app', 'chalu', 'karo', 'please'],
#  ['google+', 'open', 'kariye'],
#  ['launch', 'karo', 'settings', 'ko'],
#  ['skype', 'open', 'karne', 'me', 'madad', 'karo'],
#  ['phone', 'app', 'shuru', 'karo'],
#  ['youtube', 'chalu', 'karo', 'please'],
#  ['camera', 'chalu', 'karo'],
#  ['alarm',
#   'set',
#   'karne',
#   'ke',
#   'liye',
#   'clock',
#   'app',
#   'ko',
#   'launch',
#   'karo'],
#  ['gaana', 'music', 'app', 'launch', 'karne', 'me', 'help', 'karo'],
#  ['skype', 'start', 'kar', 'do'],
#  ['mujhe', 'samsung', 'notes', 'kholke', 'do'],
#  ['facebook', 'dobara', 'open', 'karo'],
#  ['samsung', 'health', 'app', 'shuru', 'karo'],
#  ['clock', 'app', 'chalu', 'karne', 'mein', 'help', 'karo'],
#  ['spotify', 'app', 'suru', 'kijiye'],
#  ['dailyhunt', 'app', 'open', 'kijiye'],
#  ['mera', 'linkedin', 'app', 'shuru', 'karo'],
#  ['kya', 'tum', 'google', 'maps', 'chalu', 'kar', 'sakte', 'ho?'],
#  ['mere', 'contacts', 'app', 'open', 'karo'],
#  ['samsung', 'notes', 'app', 'ko', 'khol', 'dijiye'],
#  ['meri', 'begum', 'ko', 'text', 'bhejein'],
#  ['send',
#   'text',
#   'meri',
#   'beti',
#   'ko',
#   'that',
#   "i'm",
#   'waiting',
#   'outside',
#   'college'],
#  ['ek', 'sms', 'indrani', 'chauhan', 'ko', 'bhejein'],
#  ['nani',
#   'ki',
#   'mobile',
#   'par',
#   'text',
#   'karo',
#   'ki',
#   'kaal',
#   'ayunga',
#   'aapse',
#   'milne'],
#  ['kya', 'mera', 'text', 'bhej', 'doge', 'rishikesh', 'ko?'],
#  ['send',
#   'a',
#   'message',
#   'to',
#   'mummy',
#   'ki',
#   'mein',
#   'ajj',
#   'jaldi',
#   'ayunga'],
#  ['text', 'mausa', 'ji', 'ki', 'happy', 'new', 'year'],
#  ['mujhe', 'ek', 'message', 'bhejna', 'tha', 'jaldi'],
#  ['if',
#   'possible',
#   'mera',
#   'ek',
#   'text',
#   'bhej',
#   'do',
#   'aamir',
#   'ko',
#   'ki',
#   "i'll",
#   'have',
#   'to',
#   'check'],
#  ['rashmi', 'chachi', 'ko', 'mera', 'message', 'pahuncha', 'do'],
#  ['kaavya',
#   'ko',
#   'message',
#   'bhejo',
#   'ki',
#   "i'll",
#   'be',
#   'there',
#   'in',
#   'five',
#   'mintues'],
#  ['send',
#   'text',
#   'meri',
#   'biwi',
#   'ko',
#   'not',
#   'feeling',
#   'well',
#   'so',
#   'going',
#   'home'],
#  ['bohot',
#   'wait',
#   'kar',
#   'liya',
#   'ye',
#   'message',
#   'bhej',
#   'do',
#   'navjot',
#   'ko'],
#  ['send', 'a', 'message', 'didi', 'ko', 'unke', 'ghar', 'ne', 'number', 'par'],
#  ['rishi',
#   'ko',
#   'ek',
#   'text',
#   'send',
#   'karo',
#   'ki',
#   'back',
#   'in',
#   '5',
#   'mins'],
#  ['jaldi',
#   'se',
#   'ek',
#   'text',
#   'send',
#   'kar',
#   'do',
#   'puneet',
#   'ko',
#   'ki',
#   'wo',
#   'ghar',
#   'aa',
#   'jaye',
#   'aj'],
#  ['papa',
#   'ke',
#   'liye',
#   'ek',
#   'text',
#   'message',
#   'choddhein',
#   'saying',
#   'tomorrow',
#   'meeting',
#   'with',
#   'client',
#   'got',
#   'cancelled'],
#  ['party',
#   'cancel',
#   'ho',
#   'gayi',
#   'karke',
#   'ek',
#   'message',
#   'choddh',
#   'do',
#   'group',
#   'par'],
#  ['airtel', 'sim', 'use', 'karke', 'papa', 'ko', 'message', 'bhejo'],
#  ['payal',
#   'ko',
#   'text',
#   'send',
#   'karo',
#   'to',
#   'bring',
#   'the',
#   'dress',
#   'from',
#   'the',
#   'shop'],
#  ['pizza',
#   'bake',
#   'hone',
#   'ke',
#   'liye',
#   'set',
#   'timer',
#   'for',
#   '10',
#   'minutes'],
#  ['ek', 'timer', 'to', 'lagiye'],
#  ['kripaya',
#   '4',
#   'hours',
#   '25',
#   'minutes',
#   'aur',
#   '15',
#   'seconds',
#   'ka',
#   'timer',
#   'chalu',
#   'kijiye'],
#  ['timer', 'set', 'kar', 'abi', 'cookie', 'ke', 'naam', 'ka'],
#  ['2', 'ghanta', 'ka', 'timer', 'chalu', 'karo'],
#  ['doodh', 'garam', 'karne', 'ka', 'timer', 'lagao', 'for', '5', 'minutes'],
#  ['jaldi', 'se', 'mera', 'timer', 'chalo', 'karo', 'for', '30', 'seconds'],
#  ['2', 'minute', 'wala', 'timer', 'laga', 'do', 'for', 'skipping'],
#  ['10', 'minute', 'ka', 'timer', 'chalu', 'karo', 'walking', 'naam', 'se'],
#  ['kitty',
#   'nap',
#   'timer',
#   'ko',
#   'chalo',
#   'karo',
#   '15',
#   'minute',
#   'ke',
#   'liye'],
#  ['chane',
#   'ki',
#   'daal',
#   'pakne',
#   'ka',
#   'timer',
#   'start',
#   'karo',
#   'abhi',
#   'turant'],
#  ['veg', 'chowmein', 'ka', 'timer', 'lagao', 'for', '10', 'minutes'],
#  ['test', 'timer', 'chalao'],
#  ['bhindi', 'timer', 'start', 'karo'],
#  ['start', 'a', 'timer', 'for', '2', 'hours', '45', 'minutes'],
#  ['ek', '5', 'minute', 'ka', 'meditation', 'timer', 'start', 'karo'],
#  ['sprint', 'timer', 'shuro', 'kijiye'],
#  ['crunches', 'timer', 'shuru', 'karo'],
#  ['please',
#   'ek',
#   '3',
#   'ghnte',
#   'ka',
#   'ginti',
#   'wali',
#   'ghari',
#   'suru',
#   'kariye'],
#  ['mujhe',
#   'nailpaint',
#   'naam',
#   'ka',
#   'ek',
#   'timer',
#   'abi',
#   'set',
#   'karke',
#   'do'],
#  ['remind', 'karvayega', 'raat', '8', 'baje', 'ramayan', 'is', 'on'],
#  ['2nd',
#   'october',
#   'ko',
#   'mujhe',
#   'remind',
#   'karana',
#   'ki',
#   'office',
#   'outing',
#   'hai'],
#  ['shopping', 'karke', 'ek', 'reminder', 'lagao'],
#  ['har', 'subah', 'yoga', 'reminder', 'bana', 'dijiye'],
#  ['set',
#   'an',
#   'alert',
#   'for',
#   'me',
#   'to',
#   'remind',
#   'me',
#   'about',
#   'puja',
#   'ki',
#   'haldi',
#   'ceremony',
#   'at',
#   '9',
#   'am',
#   'kal'],
#  ['kya',
#   'ek',
#   'reminder',
#   'set',
#   'kar',
#   'sakte',
#   'ho',
#   'agle',
#   'mahine',
#   'ki',
#   '2',
#   'tareekh',
#   'ka?'],
#  ['mujhe',
#   'ek',
#   'reminder',
#   'set',
#   'karna',
#   'hai',
#   'dinner',
#   'ke',
#   'naam',
#   'se',
#   'kal',
#   '7',
#   'pm',
#   'ke',
#   'liye'],
#  ['please',
#   'mere',
#   'liye',
#   'reminder',
#   'lagao',
#   'ki',
#   'office',
#   'me',
#   'conference',
#   'hai',
#   'at',
#   '4',
#   'pm',
#   'this',
#   'friday'],
#  ['please',
#   'ek',
#   'reminder',
#   'set',
#   'karke',
#   'dijiye',
#   "guddu's",
#   'birthday',
#   'on',
#   '2nd',
#   'july'],
#  ['reminder', 'set', 'karein'],
#  ['family',
#   'game',
#   'night',
#   'ke',
#   'naam',
#   'wala',
#   'ek',
#   'reminder',
#   'lagao',
#   'every',
#   'friday'],
#  ['har',
#   'varsh',
#   'paanch',
#   'july',
#   'ko',
#   'deshpande',
#   'ki',
#   'barsi',
#   'hai',
#   'yaad',
#   'rakhiyega'],
#  ['kripaya',
#   'mujhe',
#   'yaad',
#   'dilaye',
#   'ki',
#   'kal',
#   'raat',
#   'ko',
#   '9',
#   'baje',
#   'puja',
#   'ki',
#   'wedding',
#   'anniversary',
#   'party',
#   'hai'],
#  ['kya',
#   'tum',
#   'mujhe',
#   'remind',
#   'kara',
#   'sakte',
#   'ho',
#   'ki',
#   'maasi',
#   'ko',
#   'sandesh',
#   'bhejna',
#   'hai'],
#  ['meeting', 'ka', '9', 'baje', 'ka', 'reminder', 'lagao'],
#  ['mere',
#   'liye',
#   'ek',
#   'reminder',
#   'laga',
#   'agle',
#   'mahine',
#   'ke',
#   'liye',
#   'at',
#   '5',
#   'pm',
#   'for',
#   'travel',
#   'to',
#   'germany'],
#  ['har', 'roz', 'kasrat', 'karne', 'ka', 'reminder', 'set', 'karo'],
#  ['2',
#   'november',
#   'ko',
#   'mujhe',
#   'yaad',
#   'dilana',
#   'ki',
#   'doctor',
#   'appointment',
#   'hai'],
#  ['kal',
#   'routine',
#   'medical',
#   'check',
#   'up',
#   'ke',
#   'liye',
#   'ek',
#   'reminder',
#   'lagao',
#   'subah',
#   'mein'],
#  ['please',
#   'ek',
#   'bar',
#   'reminder',
#   'laga',
#   'do',
#   'raat',
#   'ko',
#   'dawai',
#   'khani',
#   'hai',
#   'backache',
#   'ki'],
#  ['kripaya', '243', 'ko', '78', 'duwara', 'guna', 'karien'],
#  ['ninety',
#   'percent',
#   'of',
#   'thirty',
#   'five',
#   'hundred',
#   'ka',
#   'value',
#   'bata',
#   'sakte',
#   'ho?'],
#  ['mujhe',
#   'calculate',
#   'karke',
#   'batao',
#   'ki',
#   'barah',
#   'guna',
#   'pachas',
#   'kitna',
#   'hota',
#   'hai?'],
#  ['calculator',
#   'use',
#   'karke',
#   'tan',
#   'three',
#   'sixty',
#   'ka',
#   'value',
#   'pata',
#   'karke',
#   'batao'],
#  ['289', 'me', 'se', '10', 'ko', 'ghata', 'karke', 'batao'],
#  ['1257', 'and', '1400', 'ka', 'jodh', 'calculate', 'karo'],
#  ['do', 'duni', 'char', 'calculate', 'kijiiye'],
#  ['pi', 'ka', 'value', 'bataiye'],
#  ['seven',
#   'lakh',
#   'minus',
#   'fifty',
#   'five',
#   'thousand',
#   'ka',
#   'value',
#   'batadho'],
#  ['cos', 'three', 'sixty', 'degree', 'ka', 'value', 'kya', 'hai'],
#  ['twenty',
#   'two',
#   'point',
#   'five',
#   'ko',
#   'seventeen',
#   'se',
#   'multiply',
#   'karo'],
#  ['pi', 'ki', 'value', 'calculate', 'karke', 'bata', 'sakte', 'ho?'],
#  ['20',
#   'lakh',
#   'ko',
#   '12',
#   'se',
#   'multiply',
#   'karo',
#   'to',
#   'kya',
#   'aata',
#   'hai?'],
#  ['one',
#   'zero',
#   'two',
#   'four',
#   'ka',
#   'square',
#   'root',
#   'calculate',
#   'kar',
#   'lo'],
#  ['cube', 'root', 'of', '21', 'kitna', 'hota', 'hai'],
#  ['please', 'calculate', 'karo', '32', 'multiplied', 'by', '358'],
#  ['400', 'ke', 'sath', '23', 'jod', 'ke', 'bataye'],
#  ['ek',
#   'chauthai',
#   'guna',
#   'teen',
#   'chauthai',
#   'calculate',
#   'kareke',
#   'batao'],
#  ['calculator',
#   'use',
#   'karke',
#   'two',
#   'to',
#   'the',
#   'power',
#   'of',
#   'twenty',
#   'two',
#   'ka',
#   'value',
#   'pata',
#   'kar',
#   'lo'],
#  ['160', 'ka', '10', '%', 'kitna', 'hua'],
#  ['turant', 'mere', 'phone', 'me', 'dark', 'mode', 'on', 'karo'],
#  ['blutooth', 'on', 'kar', 'do'],
#  ['mobile', 'hotspot', 'kripaya', 'on', 'krien'],
#  ['kripaya', 'flashlight', 'ko', 'turn', 'on', 'karien'],
#  ['kya', 'mere', 'phone', 'ka', 'bluetooth', 'on', 'hai'],
#  ['bluetooth', 'ko', 'sakriya', 'karein'],
#  ['nfc', 'ko', 'on', 'karna', 'hai'],
#  ['wifi', 'ki', 'on', 'kare'],
#  ['wi', 'fi', 'setting', 'ko', 'on', 'karen'],
#  ['kripaya', 'do', 'not', 'diturb', 'mode', 'ko', 'on', 'karo'],
#  ['please', 'torch', 'on', 'kia', 'jai'],
#  ['turn', 'on', 'wifi'],
#  ['kya', 'tum', 'torch', 'light', 'ko', 'abhi', 'band', 'kar', 'sakte', 'ho?'],
#  ['mujhe', 'jaldi', 'se', 'bluetooth', 'on', 'karke', 'do'],
#  ['please', 'sync', 'on', 'karen'],
#  ['location', 'on', 'hai', 'kya?'],
#  ['kripaya', 'power', 'mode', 'ko', 'on', 'kiya', 'jai'],
#  ['bluetooth', 'ko', 'on', 'karen'],
#  ['please', 'turn', 'nfc', 'on'],
#  ['kripaya', 'dark', 'mode', 'on', 'kar', 'sakte', 'hain'],
#  ['jitne',
#   'bhi',
#   'wednesday',
#   'ko',
#   'aaye',
#   'messages',
#   'hain',
#   'unhe',
#   'padhiye'],
#  ['kritika', 'ke', 'haal', 'hi', 'mein', 'aaye', 'message', 'ko', 'padho'],
#  ['from',
#   "amit's",
#   'messages',
#   'wo',
#   'nikalo',
#   'jismein',
#   'diwali',
#   'word',
#   'ho'],
#  ['message', 'sunao'],
#  ['tum',
#   'verma',
#   'ji',
#   'se',
#   'aaya',
#   'hua',
#   'pehla',
#   'message',
#   'read',
#   'kar',
#   'sakte',
#   'ho',
#   'kya'],
#  ['sanchit',
#   'ke',
#   'mobile',
#   'phone',
#   'se',
#   'aaya',
#   'latest',
#   'message',
#   'padhiye'],
#  ['meri',
#   'student',
#   'madhuri',
#   'se',
#   'jo',
#   'message',
#   'receive',
#   'kia',
#   'hai',
#   'padh',
#   'ke',
#   'sunao'],
#  ['pita', 'ji', 'ka', 'latest', 'message', 'padh', 'do'],
#  ['kirti', 'se', 'jo', 'message', 'aaya', 'hai', 'abhi', 'use', 'padho'],
#  ['mera', 'last', 'bheja', 'hua', 'message', 'read', 'karo'],
#  ['woh',
#   'saare',
#   'messages',
#   'dikhao',
#   'which',
#   'has',
#   'party',
#   'word',
#   'in',
#   'it'],
#  ['kya',
#   'tum',
#   'mujhe',
#   'bhaskar',
#   'ka',
#   'wo',
#   'message',
#   'jismein',
#   'usne',
#   'discussion',
#   'likha',
#   'hai',
#   'padh',
#   'doge'],
#  ['woh',
#   'saare',
#   'messages',
#   'padho',
#   'which',
#   'has',
#   'meeting',
#   'word',
#   'in',
#   'it'],
#  ['from',
#   "amit's",
#   'messages',
#   'wo',
#   'messsage',
#   'nikalo',
#   'jismein',
#   'haldi',
#   'shabd',
#   'ho'],
#  ['sabse', 'naya', 'wala', 'text', 'message', 'padho'],
#  ['15', 'jan', 'ka', 'message', 'read', 'karo', 'from', 'papa'],
#  ['ese', 'messages', 'jismein', 'account', 'ho', 'read', 'those'],
#  ['amit',
#   'ke',
#   'text',
#   'messages',
#   'mein',
#   'se',
#   'wo',
#   'wale',
#   'nikalo',
#   'jinmein',
#   'theme',
#   'park',
#   'ke',
#   'baare',
#   'mein',
#   'baat',
#   'hui',
#   'hai'],
#  ['tarun',
#   'ko',
#   'jo',
#   'maine',
#   'message',
#   'send',
#   'kiya',
#   'tha',
#   'padh',
#   'do'],
#  ['jo',
#   'sabse',
#   'aakhiri',
#   'message',
#   'aaya',
#   'hai',
#   'from',
#   'samir',
#   'use',
#   'read',
#   'kariye']]

# %%
classes = OBJ.prepareLabels()
words   = OBJ.prepareWordBag()

# %%
i = 0
result = []
for final in test_final:
  inputs = final
  inputs = inputs
  tag_scores = model(inputs)
  #print(tag_scores)

# print the most likely tag index, by grabbing the index with the maximum score!
# recall that these numbers correspond to tag2idx = {"DET": 0, "NN": 1, "V": 2}
  _, predicted_tags = torch.max(tag_scores, 1)
  print(input_text[i])
  cl  = []
  for idx, ii in enumerate(predicted_tags.numpy()):
    if input_text[i][idx] not in words:
      cl.append('')
    else:
      cl.append(classes[ii])
  print(cl)
  result.append(cl)
  i += 1
# Out:
# ['sakshi', 'ki', 'landline', 'mein', 'call', 'karo']
# ['B_Contact_Name', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'o']
# ['call', 'karo', 'chacha', 'ko', 'mobile', 'pe']
# ['o', 'o', 'B_Catchall_Phrase', 'o', 'B_Number_Type', 'o']
# ['dadaji', 'ke', 'mobile', 'pe', 'call', 'karo']
# ['', 'o', 'B_Number_Type', 'o', 'o', 'o']
# ['vinuth', 'ko', 'redial', 'karo']
# ['B_Contact_Name', 'o', 'B_App_Name', 'o']
# ['mere', 'sasurji', 'ke', 'ghar', 'wale', 'number', 'par', 'abhi', 'ke', 'abhi', 'phone', 'ghumao']
# ['o', 'I_Relation', 'o', 'B_Location', 'I_Location', 'I_Location', 'o', 'o', 'o', 'o', 'o', 'o']
# ['gudiya', 'ki', 'mobile', 'pe', 'dial', 'karo']
# ['o', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'o']
# ['meri', 'baat', 'karao', 'abhijeet', 'se', 'sim', '2', 'card', 'use', 'karna']
# ['o', 'o', 'o', 'B_Contact_Name', 'o', 'I_Component', 'I_Component', 'I_Component', 'o', 'o']
# ['mausa', 'ji', 'ko', 'jaldi', 'se', 'ring', 'back', 'karien']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'sim', '2', 'se', 'mom', 'ko', 'call', 'karna', 'hain']
# ['o', 'I_Component', 'I_Component', 'o', 'B_Contact_Name', 'o', 'o', 'o', 'o']
# ['mujhe', 'abhi', 'nani', 'se', 'baat', 'karni', 'hain']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['dadi', 'ke', 'landline', 'number', 'par', 'phone', 'karo']
# ['I_Date', 'o', 'B_Number_Type', 'I_Location', 'o', 'o', 'o']
# ['phuphi', 'ji', 'ko', 'call', 'karo']
# ['B_Relation', 'B_Contact_Name', 'o', 'o', 'o']
# ['please', 'varun', 'ko', 'phone', 'lagiyen']
# ['o', 'B_Contact_Name', 'o', 'o', 'o']
# ['rasika', 'ke', 'office', 'ke', 'number', 'par', 'call', 'please']
# ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'angad', 'se', 'baat', 'karni', 'hai']
# ['o', 'B_Contact_Name', 'o', 'o', 'o', 'o']
# ['baat', 'karao', 'zara', 'sabina', 'se']
# ['o', 'o', 'o', '', 'o']
# ['tarun', 'ki', 'durvas', 'yantra', 'mein', 'numbar', 'lagaye']
# ['I_App_Name', 'o', '', '', 'o', '', 'o']
# ['nandoi', 'ji', 'ki', 'number', 'miliyen', 'please']
# ['', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', '', 'o']
# ['waseem', 'ko', 'call', 'kariye', 'abhi', 'ke', 'abhi']
# ['', 'o', 'o', 'o', 'o', 'o', 'o']
# ['surabhi', 'ki', 'landline', 'mein', 'call', 'back', 'karien']
# ['', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'B_Location', 'o']
# ['is', 'page', 'ki', 'picture', 'click', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o']
# ['is', 'page', 'ka', 'screenshot', 'lene', 'me', 'meri', 'help', 'kar', 'do']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'I_Time', 'B_Feature/Action']
# ['screenshot', 'lijiye', 'aur', 'gallery', 'mein', 'save', 'kijiye']
# ['o', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Catchall_Phrase', 'o', 'o', 'o']
# ['please', 'capture', 'the', 'screen']
# ['o', 'o', 'o', 'o']
# ['ho', 'sake', 'to', 'is', 'page', 'ka', 'ek', 'screen', 'shot', 'le', 'lo']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'screenshot', 'chahiye']
# ['o', 'o', 'o']
# ['kripaya', 'screenshot', 'khicho']
# ['o', 'o', 'o']
# ['kripaya', 'screenshot', 'lijiye']
# ['o', 'o', 'o']
# ['kia', 'ye', 'wali', 'screen', 'k', 'chitra', 'khich', 'sakte', 'hain']
# ['o', 'o', 'o', 'o', 'o', 'o', '', 'o', 'o']
# ['mere', 'phone', 'ke', 'wallpaper', 'ka', 'screenshot', 'lo']
# ['o', 'o', 'o', '', 'o', 'o', 'o']
# ['mere', 'phopne', 'ke', 'page', 'ka', 'screenshot', 'lo']
# ['o', '', 'o', 'o', 'o', 'o', 'o']
# ['screenshot', 'le', 'le']
# ['o', 'o', 'o']
# ['ye', 'phone', 'screen', 'ki', 'picture', 'lekar', 'save', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['kia', 'screenshot', 'save', 'kar', 'sakte', 'hain']
# ['o', 'o', 'I_Catchall_Phrase', 'o', 'o', 'o']
# ['screenshot', 'ko', 'lijiye']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o']
# ['kripaya', 'screenshot', 'lene', 'k', 'baad', 'gallery', 'mein', 'save', 'karen']
# ['o', 'o', 'o', 'o', 'I_Catchall_Phrase', 'B_Catchall_Phrase', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase']
# ['take', 'a', 'picture', 'mere', 'phone', 'ke', 'display', 'page', 'ka']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['screen', 'ka', 'picture', 'ko', 'khicho']
# ['o', 'o', 'o', 'o', 'o']
# ['mere', 'phone', 'pe', 'jo', 'dikh', 'raha', 'hai', 'uska', 'screen', 'shot', 'lo']
# ['o', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o']
# ['screen', 'ki', 'picture', 'save', 'kijiye']
# ['o', 'o', 'o', 'o', 'o']
# ['wake', 'me', 'up', 'at', '11', 'pm', 'cinema', 'dekhna', 'hai', 'tv', 'pe']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', 'I_Time', 'I_Time', 'I_Catchall_Phrase', 'o', 'o']
# ['please', 'tum', 'ek', 'alarm', 'set', 'karo', 'kal', 'subah', '11', 'baje', 'ka', 'recharge', 'naam', 'se']
# ['o', 'o', 'o', 'o', 'o', 'o', 'B_Day', 'B_Time', 'I_Time', 'I_Time', 'o', 'I_Catchall_Phrase', 'o', 'o']
# ['mujhe', '30', 'minute', 'mein', 'uthao']
# ['o', 'B_Catchall_Phrase', 'I_Time', 'o', 'o']
# ['morning', 'alarm', 'create', 'kar', 'do', 'at', '6', 'in', 'the', 'morning']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time', 'I_Time', 'I_Time']
# ['saas', 'bahu', 'serial', 'wale', 'naam', 'se', 'ek', 'alarm', 'banaiye', 'har', 'guruvaar', 'raat', '8', 'baje']
# ['', '', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'o', 'o', 'B_Date', 'I_Time']
# ['kal', '5', 'ko', 'tv', 'pe', 'cinema', 'dekhna', 'hain', 'alarm', 'rakho']
# ['o', 'B_Time', 'I_Time', 'I_Time', 'o', 'I_Time', 'o', 'o', 'o', 'o']
# ['please', 'ek', 'alarm', 'set', 'karke', 'do', '3', 'baje', 'movie', 'naam', 'se']
# ['o', 'o', 'o', 'o', 'o', 'o', 'I_Catchall_Phrase', 'o', 'I_Catchall_Phrase', 'o', 'o']
# ['please', 'ek', 'alarm', 'set', 'kar', 'do', 'zara', 'for', '9', 'pm', 'tomorrow']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time']
# ['every', 'day', '8', 'pm', 'alarm', 'bajao', 'gudiya', 'ki', 'dawai', 'ke', 'naam', 'se']
# ['I_Day', 'o', 'B_Time', 'I_Time', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['subah', 'utha', 'dena', 'mujhe', '4', 'baje', 'mandir', 'jana', 'hai']
# ['B_Time', 'o', 'o', 'o', 'B_Catchall_Phrase', 'B_Time', '', 'o', 'o']
# ['alarm', 'sound', 'karein', 'kal', 'subha', '10', 'ka', 'cookery', 'show', 'naam', 'rakhlo']
# ['o', '', 'o', 'o', 'o', 'B_Time', 'o', '', 'o', 'o', 'o']
# ['yoga', 'abhyas', 'ke', 'naam', 'se', 'har', 'tuesday', 'aur', 'thursday', '5:30', 'pm', 'ka', 'alarm', 'set', 'karein']
# ['o', '', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'I_Catchall_Phrase', 'B_Time', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o']
# ['mera', 'exam', 'hai', 'kal', 'subah', 'jaldi', 'utha', 'dena', '5', 'baje']
# ['o', 'B_Feature/Action', 'o', 'o', 'B_Time', 'B_Catchall_Phrase', 'o', 'o', 'B_Time', 'I_Time']
# ['alarm', 'lagao', 'agle', 'hafte', 'wednesday', 'ko', '6:16', 'par']
# ['I_Time', 'o', 'B_Day', 'I_Day', 'B_Day', 'o', '', 'o']
# ['dadu', 'ka', 'physiotherapy', 'ke', 'name', 'se', 'har', 'saturday', '9', 'am', 'ki', 'alarm', 'set', 'karein']
# ['', 'o', '', 'o', 'o', 'o', 'B_Time', 'I_Recurrance', 'o', 'I_Time', 'o', 'o', 'o', 'o']
# ['mujhe', 'raat', 'ko', 'jaldi', 'khana', 'kha', 'lena', 'hai', '9', 'baje', 'dinner', 'ka', 'alarm', 'lagao']
# ['o', 'o', 'o', 'B_Time', 'o', '', 'o', 'o', 'o', 'I_Time', 'B_Contact_Name', 'o', 'o', 'o']
# ['cookery', 'show', 'title', 'pe', 'ek', 'alarm', 'lagao', 'every', 'wednesday', 'at', '10', 'am']
# ['', 'o', 'o', 'o', 'o', 'o', 'o', 'B_App_Name', 'I_Time', 'o', 'B_Date', 'I_Time']
# ['subha', '9', 'baje', 'jaga', 'dena']
# ['o', 'o', 'o', '', 'o']
# ['alarm', 'rakhlo', 'parso', '11', 'baje', 'ka', 'football', 'practice', 'ke', 'naam', 'pe']
# ['o', 'o', 'o', 'B_Catchall_Phrase', 'I_Time', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'I_Catchall_Phrase']
# ['kal', 'subah', '8', 'baje', 'ka', 'alarm', 'lagao', 'naam', 'wake', 'up', 'rakho']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'I_Location', 'o']
# ['act', 'fibernet', 'app', 'chalu', 'karo', 'please']
# ['', '', 'o', 'o', 'o', 'o']
# ['google+', 'open', 'kariye']
# ['', 'o', 'o']
# ['launch', 'karo', 'settings', 'ko']
# ['o', 'o', 'B_App_Name', 'o']
# ['skype', 'open', 'karne', 'me', 'madad', 'karo']
# ['B_App_Name', 'o', 'o', 'o', 'o', 'o']
# ['phone', 'app', 'shuru', 'karo']
# ['B_App_Name', 'o', 'o', 'o']
# ['youtube', 'chalu', 'karo', 'please']
# ['B_App_Name', 'o', 'o', 'o']
# ['camera', 'chalu', 'karo']
# ['B_App_Name', 'o', 'o']
# ['alarm', 'set', 'karne', 'ke', 'liye', 'clock', 'app', 'ko', 'launch', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o', 'I_App_Name', 'o', 'o', 'o']
# ['gaana', 'music', 'app', 'launch', 'karne', 'me', 'help', 'karo']
# ['I_App_Name', 'I_App_Name', 'o', 'o', 'o', 'o', 'o', 'o']
# ['skype', 'start', 'kar', 'do']
# ['B_App_Name', 'o', 'o', 'o']
# ['mujhe', 'samsung', 'notes', 'kholke', 'do']
# ['o', 'o', '', '', 'o']
# ['facebook', 'dobara', 'open', 'karo']
# ['B_App_Name', '', 'o', 'o']
# ['samsung', 'health', 'app', 'shuru', 'karo']
# ['B_App_Name', '', 'o', 'o', 'o']
# ['clock', 'app', 'chalu', 'karne', 'mein', 'help', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['spotify', 'app', 'suru', 'kijiye']
# ['B_Catchall_Phrase', 'o', 'o', 'o']
# ['dailyhunt', 'app', 'open', 'kijiye']
# ['', 'o', 'o', 'o']
# ['mera', 'linkedin', 'app', 'shuru', 'karo']
# ['o', '', 'I_App_Name', 'o', 'o']
# ['kya', 'tum', 'google', 'maps', 'chalu', 'kar', 'sakte', 'ho?']
# ['o', 'o', 'B_App_Name', 'o', 'o', 'o', 'o', 'o']
# ['mere', 'contacts', 'app', 'open', 'karo']
# ['B_Relation', 'B_Relation', 'o', 'o', 'o']
# ['samsung', 'notes', 'app', 'ko', 'khol', 'dijiye']
# ['B_Feature/Action', '', 'I_Catchall_Phrase', 'o', 'o', 'o']
# ['meri', 'begum', 'ko', 'text', 'bhejein']
# ['o', '', 'o', 'o', 'o']
# ['send', 'text', 'meri', 'beti', 'ko', 'that', "i'm", 'waiting', 'outside', 'college']
# ['o', 'o', 'B_Catchall_Phrase', 'I_Relation', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', '', 'I_Catchall_Phrase']
# ['ek', 'sms', 'indrani', 'chauhan', 'ko', 'bhejein']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', '', 'o', 'o']
# ['nani', 'ki', 'mobile', 'par', 'text', 'karo', 'ki', 'kaal', 'ayunga', 'aapse', 'milne']
# ['o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o', '', '', '', 'I_Day']
# ['kya', 'mera', 'text', 'bhej', 'doge', 'rishikesh', 'ko?']
# ['o', 'o', 'o', 'o', 'o', '', 'o']
# ['send', 'a', 'message', 'to', 'mummy', 'ki', 'mein', 'ajj', 'jaldi', 'ayunga']
# ['o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'I_Catchall_Phrase', '', 'I_Catchall_Phrase', '']
# ['text', 'mausa', 'ji', 'ki', 'happy', 'new', 'year']
# ['o', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Catchall_Phrase', 'I_Catchall_Phrase', '']
# ['mujhe', 'ek', 'message', 'bhejna', 'tha', 'jaldi']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'I_Catchall_Phrase', 'B_Catchall_Phrase']
# ['if', 'possible', 'mera', 'ek', 'text', 'bhej', 'do', 'aamir', 'ko', 'ki', "i'll", 'have', 'to', 'check']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', '', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o']
# ['rashmi', 'chachi', 'ko', 'mera', 'message', 'pahuncha', 'do']
# ['', 'o', 'o', 'o', 'o', 'o', 'o']
# ['kaavya', 'ko', 'message', 'bhejo', 'ki', "i'll", 'be', 'there', 'in', 'five', 'mintues']
# ['o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'B_Recurrance', '']
# ['send', 'text', 'meri', 'biwi', 'ko', 'not', 'feeling', 'well', 'so', 'going', 'home']
# ['o', 'o', 'I_Feature/Action', 'I_Feature/Action', 'o', 'B_Contact_Name', 'I_Relation', 'o', 'B_Catchall_Phrase', '', 'o']
# ['bohot', 'wait', 'kar', 'liya', 'ye', 'message', 'bhej', 'do', 'navjot', 'ko']
# ['', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', '', 'o']
# ['send', 'a', 'message', 'didi', 'ko', 'unke', 'ghar', 'ne', 'number', 'par']
# ['o', 'o', 'o', 'I_Catchall_Phrase', 'o', 'o', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o']
# ['rishi', 'ko', 'ek', 'text', 'send', 'karo', 'ki', 'back', 'in', '5', 'mins']
# ['', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o']
# ['jaldi', 'se', 'ek', 'text', 'send', 'kar', 'do', 'puneet', 'ko', 'ki', 'wo', 'ghar', 'aa', 'jaye', 'aj']
# ['B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'B_Feature/Action', '', 'o', 'o', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase']
# ['papa', 'ke', 'liye', 'ek', 'text', 'message', 'choddhein', 'saying', 'tomorrow', 'meeting', 'with', 'client', 'got', 'cancelled']
# ['B_Time', 'I_Time', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', '', 'o', 'o']
# ['party', 'cancel', 'ho', 'gayi', 'karke', 'ek', 'message', 'choddh', 'do', 'group', 'par']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'B_Message_Type', 'o']
# ['airtel', 'sim', 'use', 'karke', 'papa', 'ko', 'message', 'bhejo']
# ['B_App_Name', 'I_Component', 'B_App_Name', 'o', 'B_Relation', 'o', 'o', 'o']
# ['payal', 'ko', 'text', 'send', 'karo', 'to', 'bring', 'the', 'dress', 'from', 'the', 'shop']
# ['', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'B_Catchall_Phrase', '', 'o', 'I_Catchall_Phrase', 'B_Catchall_Phrase']
# ['pizza', 'bake', 'hone', 'ke', 'liye', 'set', 'timer', 'for', '10', 'minutes']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time']
# ['ek', 'timer', 'to', 'lagiye']
# ['B_Time', 'o', 'o', 'o']
# ['kripaya', '4', 'hours', '25', 'minutes', 'aur', '15', 'seconds', 'ka', 'timer', 'chalu', 'kijiye']
# ['o', 'I_Time', '', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', 'B_Date', 'o', 'o', 'o', 'o']
# ['timer', 'set', 'kar', 'abi', 'cookie', 'ke', 'naam', 'ka']
# ['o', 'o', 'o', 'o', '', 'o', 'o', 'o']
# ['2', 'ghanta', 'ka', 'timer', 'chalu', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o']
# ['doodh', 'garam', 'karne', 'ka', 'timer', 'lagao', 'for', '5', 'minutes']
# ['I_Catchall_Phrase', '', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time']
# ['jaldi', 'se', 'mera', 'timer', 'chalo', 'karo', 'for', '30', 'seconds']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time']
# ['2', 'minute', 'wala', 'timer', 'laga', 'do', 'for', 'skipping']
# ['I_Time', 'I_Time', 'o', 'o', 'o', 'o', 'o', '']
# ['10', 'minute', 'ka', 'timer', 'chalu', 'karo', 'walking', 'naam', 'se']
# ['B_Time', 'I_Time', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o']
# ['kitty', 'nap', 'timer', 'ko', 'chalo', 'karo', '15', 'minute', 'ke', 'liye']
# ['o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time', 'o', 'o']
# ['chane', 'ki', 'daal', 'pakne', 'ka', 'timer', 'start', 'karo', 'abhi', 'turant']
# ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['veg', 'chowmein', 'ka', 'timer', 'lagao', 'for', '10', 'minutes']
# ['', '', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time']
# ['test', 'timer', 'chalao']
# ['I_Time', 'o', 'o']
# ['bhindi', 'timer', 'start', 'karo']
# ['I_Catchall_Phrase', 'o', 'o', 'o']
# ['start', 'a', 'timer', 'for', '2', 'hours', '45', 'minutes']
# ['o', 'o', 'o', 'o', 'B_Time', '', 'B_Catchall_Phrase', 'o']
# ['ek', '5', 'minute', 'ka', 'meditation', 'timer', 'start', 'karo']
# ['o', 'B_Time', 'I_Time', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o']
# ['sprint', 'timer', 'shuro', 'kijiye']
# ['', 'o', 'o', 'o']
# ['crunches', 'timer', 'shuru', 'karo']
# ['', 'o', 'o', 'o']
# ['please', 'ek', '3', 'ghnte', 'ka', 'ginti', 'wali', 'ghari', 'suru', 'kariye']
# ['o', 'o', 'B_Time', '', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'nailpaint', 'naam', 'ka', 'ek', 'timer', 'abi', 'set', 'karke', 'do']
# ['o', '', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['remind', 'karvayega', 'raat', '8', 'baje', 'ramayan', 'is', 'on']
# ['o', '', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', '', 'o', 'o']
# ['2nd', 'october', 'ko', 'mujhe', 'remind', 'karana', 'ki', 'office', 'outing', 'hai']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', '', 'I_Catchall_Phrase']
# ['shopping', 'karke', 'ek', 'reminder', 'lagao']
# ['o', 'o', 'o', 'o', 'o']
# ['har', 'subah', 'yoga', 'reminder', 'bana', 'dijiye']
# ['B_Recurrance', 'I_Time', 'B_Catchall_Phrase', 'B_Time', 'o', 'o']
# ['set', 'an', 'alert', 'for', 'me', 'to', 'remind', 'me', 'about', 'puja', 'ki', 'haldi', 'ceremony', 'at', '9', 'am', 'kal']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', '', 'B_Day', 'I_Catchall_Phrase', '', '', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Day']
# ['kya', 'ek', 'reminder', 'set', 'kar', 'sakte', 'ho', 'agle', 'mahine', 'ki', '2', 'tareekh', 'ka?']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Time', 'I_Time', 'o']
# ['mujhe', 'ek', 'reminder', 'set', 'karna', 'hai', 'dinner', 'ke', 'naam', 'se', 'kal', '7', 'pm', 'ke', 'liye']
# ['o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'I_Time', 'o', 'o']
# ['please', 'mere', 'liye', 'reminder', 'lagao', 'ki', 'office', 'me', 'conference', 'hai', 'at', '4', 'pm', 'this', 'friday']
# ['o', 'o', 'o', 'o', 'o', 'o', 'B_Location', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Day']
# ['please', 'ek', 'reminder', 'set', 'karke', 'dijiye', "guddu's", 'birthday', 'on', '2nd', 'july']
# ['o', 'o', 'o', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o']
# ['reminder', 'set', 'karein']
# ['o', 'o', 'o']
# ['family', 'game', 'night', 'ke', 'naam', 'wala', 'ek', 'reminder', 'lagao', 'every', 'friday']
# ['B_App_Name', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o', 'B_App_Name', 'B_Date']
# ['har', 'varsh', 'paanch', 'july', 'ko', 'deshpande', 'ki', 'barsi', 'hai', 'yaad', 'rakhiyega']
# ['B_Recurrance', 'I_Recurrance', 'B_Catchall_Phrase', 'I_Time', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', '', 'I_Catchall_Phrase', 'o', '']
# ['kripaya', 'mujhe', 'yaad', 'dilaye', 'ki', 'kal', 'raat', 'ko', '9', 'baje', 'puja', 'ki', 'wedding', 'anniversary', 'party', 'hai']
# ['o', 'o', 'o', '', 'o', 'o', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase']
# ['kya', 'tum', 'mujhe', 'remind', 'kara', 'sakte', 'ho', 'ki', 'maasi', 'ko', 'sandesh', 'bhejna', 'hai']
# ['o', 'B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['meeting', 'ka', '9', 'baje', 'ka', 'reminder', 'lagao']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o']
# ['mere', 'liye', 'ek', 'reminder', 'laga', 'agle', 'mahine', 'ke', 'liye', 'at', '5', 'pm', 'for', 'travel', 'to', 'germany']
# ['o', 'o', 'o', 'o', 'o', 'B_Day', 'I_Month', 'o', 'o', 'o', 'B_Time', 'o', 'o', '', 'B_Day', '']
# ['har', 'roz', 'kasrat', 'karne', 'ka', 'reminder', 'set', 'karo']
# ['B_Recurrance', 'o', '', 'o', 'o', 'o', 'o', 'o']
# ['2', 'november', 'ko', 'mujhe', 'yaad', 'dilana', 'ki', 'doctor', 'appointment', 'hai']
# ['B_Time', 'I_Date', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o']
# ['kal', 'routine', 'medical', 'check', 'up', 'ke', 'liye', 'ek', 'reminder', 'lagao', 'subah', 'mein']
# ['B_Day', 'I_Catchall_Phrase', '', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'o']
# ['please', 'ek', 'bar', 'reminder', 'laga', 'do', 'raat', 'ko', 'dawai', 'khani', 'hai', 'backache', 'ki']
# ['o', 'o', 'o', 'o', 'o', 'o', 'I_Time', 'I_Time', 'I_Catchall_Phrase', 'I_Time', 'I_Catchall_Phrase', '', 'I_Catchall_Phrase']
# ['kripaya', '243', 'ko', '78', 'duwara', 'guna', 'karien']
# ['o', '', 'o', '', 'B_Feature/Action', 'I_Recurrance', 'o']
# ['ninety', 'percent', 'of', 'thirty', 'five', 'hundred', 'ka', 'value', 'bata', 'sakte', 'ho?']
# ['o', 'o', 'o', 'o', 'I_Time', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'calculate', 'karke', 'batao', 'ki', 'barah', 'guna', 'pachas', 'kitna', 'hota', 'hai?']
# ['B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'B_Feature/Action', '', 'o', 'o', 'o']
# ['calculator', 'use', 'karke', 'tan', 'three', 'sixty', 'ka', 'value', 'pata', 'karke', 'batao']
# ['o', 'o', 'o', 'B_Feature/Action', 'o', 'B_Location', 'o', 'B_Feature/Action', 'B_Catchall_Phrase', 'o', 'o']
# ['289', 'me', 'se', '10', 'ko', 'ghata', 'karke', 'batao']
# ['', 'I_Catchall_Phrase', 'o', 'B_Time', 'o', 'B_Feature/Action', 'o', 'I_Feature/Action']
# ['1257', 'and', '1400', 'ka', 'jodh', 'calculate', 'karo']
# ['', 'o', '', 'o', '', 'o', 'o']
# ['do', 'duni', 'char', 'calculate', 'kijiiye']
# ['B_Feature/Action', '', 'I_Feature/Action', 'o', '']
# ['pi', 'ka', 'value', 'bataiye']
# ['o', 'o', 'B_Feature/Action', '']
# ['seven', 'lakh', 'minus', 'fifty', 'five', 'thousand', 'ka', 'value', 'batadho']
# ['B_Feature/Action', 'I_Time', 'B_Feature/Action', 'o', 'B_Time', 'o', 'o', 'B_Feature/Action', '']
# ['cos', 'three', 'sixty', 'degree', 'ka', 'value', 'kya', 'hai']
# ['o', 'o', 'o', '', 'o', 'o', 'o', 'o']
# ['twenty', 'two', 'point', 'five', 'ko', 'seventeen', 'se', 'multiply', 'karo']
# ['B_Catchall_Phrase', 'B_Catchall_Phrase', 'I_Day', 'I_Catchall_Phrase', 'I_Date', '', 'o', 'B_Feature/Action', 'o']
# ['pi', 'ki', 'value', 'calculate', 'karke', 'bata', 'sakte', 'ho?']
# ['o', 'o', 'B_Feature/Action', 'o', 'o', 'o', 'o', 'o']
# ['20', 'lakh', 'ko', '12', 'se', 'multiply', 'karo', 'to', 'kya', 'aata', 'hai?']
# ['B_Time', 'o', 'B_Time', 'B_Time', 'o', 'B_Feature/Action', 'o', 'o', 'o', 'o', 'o']
# ['one', 'zero', 'two', 'four', 'ka', 'square', 'root', 'calculate', 'kar', 'lo']
# ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'B_Feature/Action', 'I_Catchall_Phrase', 'o', 'o', 'o']
# ['cube', 'root', 'of', '21', 'kitna', 'hota', 'hai']
# ['B_Feature/Action', 'o', 'o', '', 'o', 'o', 'o']
# ['please', 'calculate', 'karo', '32', 'multiplied', 'by', '358']
# ['o', 'o', 'o', '', 'B_Feature/Action', 'o', '']
# ['400', 'ke', 'sath', '23', 'jod', 'ke', 'bataye']
# ['', 'o', 'o', 'B_Catchall_Phrase', '', 'o', '']
# ['ek', 'chauthai', 'guna', 'teen', 'chauthai', 'calculate', 'kareke', 'batao']
# ['o', 'o', 'B_Feature/Action', 'o', 'I_Time', 'o', '', 'o']
# ['calculator', 'use', 'karke', 'two', 'to', 'the', 'power', 'of', 'twenty', 'two', 'ka', 'value', 'pata', 'kar', 'lo']
# ['B_Feature/Action', 'o', 'o', 'o', 'o', 'o', 'I_Feature/Action', 'o', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'B_Catchall_Phrase', 'o', 'o']
# ['160', 'ka', '10', '%', 'kitna', 'hua']
# ['', 'o', 'o', '', 'o', 'o']
# ['turant', 'mere', 'phone', 'me', 'dark', 'mode', 'on', 'karo']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['blutooth', 'on', 'kar', 'do']
# ['', 'o', 'o', 'o']
# ['mobile', 'hotspot', 'kripaya', 'on', 'krien']
# ['B_Number_Type', 'B_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', '']
# ['kripaya', 'flashlight', 'ko', 'turn', 'on', 'karien']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o']
# ['kya', 'mere', 'phone', 'ka', 'bluetooth', 'on', 'hai']
# ['o', 'o', 'o', 'o', 'B_Feature/Action', 'o', 'o']
# ['bluetooth', 'ko', 'sakriya', 'karein']
# ['B_Feature/Action', 'B_Catchall_Phrase', 'o', 'o']
# ['nfc', 'ko', 'on', 'karna', 'hai']
# ['B_Day', 'o', 'o', 'o', 'o']
# ['wifi', 'ki', 'on', 'kare']
# ['B_Feature/Action', 'o', 'I_Catchall_Phrase', 'o']
# ['wi', 'fi', 'setting', 'ko', 'on', 'karen']
# ['B_Feature/Action', 'I_Feature/Action', '', 'o', 'o', 'o']
# ['kripaya', 'do', 'not', 'diturb', 'mode', 'ko', 'on', 'karo']
# ['o', 'I_Time', 'I_Time', '', 'I_Time', 'o', 'o', 'o']
# ['please', 'torch', 'on', 'kia', 'jai']
# ['o', 'B_Feature/Action', 'o', 'o', 'o']
# ['turn', 'on', 'wifi']
# ['o', 'o', 'B_Feature/Action']
# ['kya', 'tum', 'torch', 'light', 'ko', 'abhi', 'band', 'kar', 'sakte', 'ho?']
# ['o', 'o', 'B_Feature/Action', 'B_Contact_Name', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mujhe', 'jaldi', 'se', 'bluetooth', 'on', 'karke', 'do']
# ['o', 'B_Time', 'o', 'B_Feature/Action', 'o', 'o', 'o']
# ['please', 'sync', 'on', 'karen']
# ['o', 'B_Feature/Action', 'o', 'o']
# ['location', 'on', 'hai', 'kya?']
# ['I_Time', 'I_Catchall_Phrase', 'o', 'o']
# ['kripaya', 'power', 'mode', 'ko', 'on', 'kiya', 'jai']
# ['I_Catchall_Phrase', 'o', 'I_Time', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Catchall_Phrase']
# ['bluetooth', 'ko', 'on', 'karen']
# ['I_Catchall_Phrase', 'o', 'I_Catchall_Phrase', 'I_Catchall_Phrase']
# ['please', 'turn', 'nfc', 'on']
# ['o', 'o', 'o', 'o']
# ['kripaya', 'dark', 'mode', 'on', 'kar', 'sakte', 'hain']
# ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', 'I_Time', 'o', 'o', 'o']
# ['jitne', 'bhi', 'wednesday', 'ko', 'aaye', 'messages', 'hain', 'unhe', 'padhiye']
# ['o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o']
# ['kritika', 'ke', 'haal', 'hi', 'mein', 'aaye', 'message', 'ko', 'padho']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['from', "amit's", 'messages', 'wo', 'nikalo', 'jismein', 'diwali', 'word', 'ho']
# ['o', '', 'o', 'o', 'o', 'o', 'B_Number_Type', 'o', 'o']
# ['message', 'sunao']
# ['o', 'o']
# ['tum', 'verma', 'ji', 'se', 'aaya', 'hua', 'pehla', 'message', 'read', 'kar', 'sakte', 'ho', 'kya']
# ['o', '', 'B_Recurrance', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o']
# ['sanchit', 'ke', 'mobile', 'phone', 'se', 'aaya', 'latest', 'message', 'padhiye']
# ['', 'o', 'o', 'o', 'o', 'o', 'B_Feature/Action', 'o', 'o']
# ['meri', 'student', 'madhuri', 'se', 'jo', 'message', 'receive', 'kia', 'hai', 'padh', 'ke', 'sunao']
# ['o', '', '', 'o', 'o', 'o', 'B_Contact_Name', 'o', 'o', 'o', 'o', 'o']
# ['pita', 'ji', 'ka', 'latest', 'message', 'padh', 'do']
# ['B_Relation', 'I_Relation', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o']
# ['kirti', 'se', 'jo', 'message', 'aaya', 'hai', 'abhi', 'use', 'padho']
# ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['mera', 'last', 'bheja', 'hua', 'message', 'read', 'karo']
# ['o', 'B_Feature/Action', 'I_Feature/Action', 'o', 'o', 'o', 'o']
# ['woh', 'saare', 'messages', 'dikhao', 'which', 'has', 'party', 'word', 'in', 'it']
# ['o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o']
# ['kya', 'tum', 'mujhe', 'bhaskar', 'ka', 'wo', 'message', 'jismein', 'usne', 'discussion', 'likha', 'hai', 'padh', 'doge']
# ['o', 'o', 'o', '', 'o', 'o', 'o', 'o', 'o', 'B_Location', 'o', 'o', 'o', 'o']
# ['woh', 'saare', 'messages', 'padho', 'which', 'has', 'meeting', 'word', 'in', 'it']
# ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['from', "amit's", 'messages', 'wo', 'messsage', 'nikalo', 'jismein', 'haldi', 'shabd', 'ho']
# ['o', '', 'o', 'o', '', 'o', 'o', '', 'o', 'o']
# ['sabse', 'naya', 'wala', 'text', 'message', 'padho']
# ['o', 'B_Feature/Action', 'I_Feature/Action', 'o', 'o', 'o']
# ['15', 'jan', 'ka', 'message', 'read', 'karo', 'from', 'papa']
# ['B_App_Name', '', 'o', 'o', 'o', 'o', 'o', 'B_Relation']
# ['ese', 'messages', 'jismein', 'account', 'ho', 'read', 'those']
# ['B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o']
# ['amit', 'ke', 'text', 'messages', 'mein', 'se', 'wo', 'wale', 'nikalo', 'jinmein', 'theme', 'park', 'ke', 'baare', 'mein', 'baat', 'hui', 'hai']
# ['B_Feature/Action', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', '', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o']
# ['tarun', 'ko', 'jo', 'maine', 'message', 'send', 'kiya', 'tha', 'padh', 'do']
# ['B_Relation', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o']
# ['jo', 'sabse', 'aakhiri', 'message', 'aaya', 'hai', 'from', 'samir', 'use', 'read', 'kariye']
# ['o', 'B_Relation', 'B_Date', 'o', 'o', 'o', 'o', '', 'o', 'o', 'o']

# %%
result
# Out:
# [['B_Contact_Name', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'o'],
#  ['o', 'o', 'B_Catchall_Phrase', 'o', 'B_Number_Type', 'o'],
#  ['', 'o', 'B_Number_Type', 'o', 'o', 'o'],
#  ['B_Contact_Name', 'o', 'B_App_Name', 'o'],
#  ['o',
#   'I_Relation',
#   'o',
#   'B_Location',
#   'I_Location',
#   'I_Location',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   'B_Contact_Name',
#   'o',
#   'I_Component',
#   'I_Component',
#   'I_Component',
#   'o',
#   'o'],
#  ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o',
#   'I_Component',
#   'I_Component',
#   'o',
#   'B_Contact_Name',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['I_Date', 'o', 'B_Number_Type', 'I_Location', 'o', 'o', 'o'],
#  ['B_Relation', 'B_Contact_Name', 'o', 'o', 'o'],
#  ['o', 'B_Contact_Name', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'B_Contact_Name', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', '', 'o'],
#  ['I_App_Name', 'o', '', '', 'o', '', 'o'],
#  ['', 'I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', '', 'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['', 'o', 'B_Number_Type', 'I_Number_Type', 'o', 'B_Location', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'I_Time', 'B_Feature/Action'],
#  ['o',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o'],
#  ['o', 'o', 'o'],
#  ['o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', '', 'o', 'o'],
#  ['o', 'o', 'o', '', 'o', 'o', 'o'],
#  ['o', '', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'I_Catchall_Phrase', 'o', 'o', 'o'],
#  ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase'],
#  ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o'],
#  ['B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Time',
#   'I_Time',
#   'I_Time',
#   'I_Catchall_Phrase',
#   'o',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Day',
#   'B_Time',
#   'I_Time',
#   'I_Time',
#   'o',
#   'I_Catchall_Phrase',
#   'o',
#   'o'],
#  ['o', 'B_Catchall_Phrase', 'I_Time', 'o', 'o'],
#  ['B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'I_Time',
#   'I_Time',
#   'I_Time'],
#  ['',
#   '',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'o',
#   'o',
#   'B_Date',
#   'I_Time'],
#  ['o', 'B_Time', 'I_Time', 'I_Time', 'o', 'I_Time', 'o', 'o', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'o',
#   'I_Catchall_Phrase',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time'],
#  ['I_Day', 'o', 'B_Time', 'I_Time', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Time', 'o', 'o', 'o', 'B_Catchall_Phrase', 'B_Time', '', 'o', 'o'],
#  ['o', '', 'o', 'o', 'o', 'B_Time', 'o', '', 'o', 'o', 'o'],
#  ['o',
#   '',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'B_Time',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o',
#   'B_Feature/Action',
#   'o',
#   'o',
#   'B_Time',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'B_Time',
#   'I_Time'],
#  ['I_Time', 'o', 'B_Day', 'I_Day', 'B_Day', 'o', '', 'o'],
#  ['',
#   'o',
#   '',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'I_Recurrance',
#   'o',
#   'I_Time',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'B_Time',
#   'o',
#   '',
#   'o',
#   'o',
#   'o',
#   'I_Time',
#   'B_Contact_Name',
#   'o',
#   'o',
#   'o'],
#  ['',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_App_Name',
#   'I_Time',
#   'o',
#   'B_Date',
#   'I_Time'],
#  ['o', 'o', 'o', '', 'o'],
#  ['o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Time',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'I_Catchall_Phrase'],
#  ['I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Time',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Location',
#   'o'],
#  ['', '', 'o', 'o', 'o', 'o'],
#  ['', 'o', 'o'],
#  ['o', 'o', 'B_App_Name', 'o'],
#  ['B_App_Name', 'o', 'o', 'o', 'o', 'o'],
#  ['B_App_Name', 'o', 'o', 'o'],
#  ['B_App_Name', 'o', 'o', 'o'],
#  ['B_App_Name', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'I_App_Name', 'o', 'o', 'o'],
#  ['I_App_Name', 'I_App_Name', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['B_App_Name', 'o', 'o', 'o'],
#  ['o', 'o', '', '', 'o'],
#  ['B_App_Name', '', 'o', 'o'],
#  ['B_App_Name', '', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Catchall_Phrase', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o'],
#  ['o', '', 'I_App_Name', 'o', 'o'],
#  ['o', 'o', 'B_App_Name', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Relation', 'B_Relation', 'o', 'o', 'o'],
#  ['B_Feature/Action', '', 'I_Catchall_Phrase', 'o', 'o', 'o'],
#  ['o', '', 'o', 'o', 'o'],
#  ['o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Relation',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   '',
#   'I_Catchall_Phrase'],
#  ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', '', 'o', 'o'],
#  ['o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o', '', '', '', 'I_Day'],
#  ['o', 'o', 'o', 'o', 'o', '', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'o',
#   'I_Catchall_Phrase',
#   '',
#   'I_Catchall_Phrase',
#   ''],
#  ['o',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   ''],
#  ['B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   '',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'B_Recurrance',
#   ''],
#  ['o',
#   'o',
#   'I_Feature/Action',
#   'I_Feature/Action',
#   'o',
#   'B_Contact_Name',
#   'I_Relation',
#   'o',
#   'B_Catchall_Phrase',
#   '',
#   'o'],
#  ['',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   '',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o'],
#  ['',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'o'],
#  ['B_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Feature/Action',
#   '',
#   'o',
#   'o',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase'],
#  ['B_Time',
#   'I_Time',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   '',
#   'o',
#   'o'],
#  ['I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Message_Type',
#   'o'],
#  ['B_App_Name', 'I_Component', 'B_App_Name', 'o', 'B_Relation', 'o', 'o', 'o'],
#  ['',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   '',
#   'o',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time'],
#  ['B_Time', 'o', 'o', 'o'],
#  ['o',
#   'I_Time',
#   '',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Time',
#   'B_Date',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o', '', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o'],
#  ['I_Catchall_Phrase',
#   '',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'I_Time'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time'],
#  ['I_Time', 'I_Time', 'o', 'o', 'o', 'o', 'o', ''],
#  ['B_Time', 'I_Time', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time', 'o', 'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['', '', 'o', 'o', 'o', 'o', 'B_Time', 'I_Time'],
#  ['I_Time', 'o', 'o'],
#  ['I_Catchall_Phrase', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'B_Time', '', 'B_Catchall_Phrase', 'o'],
#  ['o', 'B_Time', 'I_Time', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o'],
#  ['o', 'o', 'B_Time', '', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', '', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o',
#   '',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   '',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', '', 'I_Catchall_Phrase'],
#  ['o', 'o', 'o', 'o', 'o'],
#  ['B_Recurrance', 'I_Time', 'B_Catchall_Phrase', 'B_Time', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   '',
#   'B_Day',
#   'I_Catchall_Phrase',
#   '',
#   '',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Day'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Time',
#   'I_Time',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'I_Time',
#   'o',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Location',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Day'],
#  ['o', 'o', 'o', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o'],
#  ['B_App_Name', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o', 'B_App_Name', 'B_Date'],
#  ['B_Recurrance',
#   'I_Recurrance',
#   'B_Catchall_Phrase',
#   'I_Time',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   '',
#   'I_Catchall_Phrase',
#   'o',
#   ''],
#  ['o',
#   'o',
#   'o',
#   '',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase'],
#  ['o',
#   'B_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['B_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Day',
#   'I_Month',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'o',
#   'o',
#   '',
#   'B_Day',
#   ''],
#  ['B_Recurrance', 'o', '', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Time', 'I_Date', 'o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o'],
#  ['B_Day',
#   'I_Catchall_Phrase',
#   '',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Time',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'I_Time',
#   'I_Time',
#   'I_Catchall_Phrase',
#   'I_Time',
#   'I_Catchall_Phrase',
#   '',
#   'I_Catchall_Phrase'],
#  ['o', '', 'o', '', 'B_Feature/Action', 'I_Recurrance', 'o'],
#  ['o', 'o', 'o', 'o', 'I_Time', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Catchall_Phrase',
#   'B_Feature/Action',
#   '',
#   'o',
#   'o',
#   'o'],
#  ['o',
#   'o',
#   'o',
#   'B_Feature/Action',
#   'o',
#   'B_Location',
#   'o',
#   'B_Feature/Action',
#   'B_Catchall_Phrase',
#   'o',
#   'o'],
#  ['',
#   'I_Catchall_Phrase',
#   'o',
#   'B_Time',
#   'o',
#   'B_Feature/Action',
#   'o',
#   'I_Feature/Action'],
#  ['', 'o', '', 'o', '', 'o', 'o'],
#  ['B_Feature/Action', '', 'I_Feature/Action', 'o', ''],
#  ['o', 'o', 'B_Feature/Action', ''],
#  ['B_Feature/Action',
#   'I_Time',
#   'B_Feature/Action',
#   'o',
#   'B_Time',
#   'o',
#   'o',
#   'B_Feature/Action',
#   ''],
#  ['o', 'o', 'o', '', 'o', 'o', 'o', 'o'],
#  ['B_Catchall_Phrase',
#   'B_Catchall_Phrase',
#   'I_Day',
#   'I_Catchall_Phrase',
#   'I_Date',
#   '',
#   'o',
#   'B_Feature/Action',
#   'o'],
#  ['o', 'o', 'B_Feature/Action', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Time',
#   'o',
#   'B_Time',
#   'B_Time',
#   'o',
#   'B_Feature/Action',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'B_Feature/Action',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o'],
#  ['B_Feature/Action', 'o', 'o', '', 'o', 'o', 'o'],
#  ['o', 'o', 'o', '', 'B_Feature/Action', 'o', ''],
#  ['', 'o', 'o', 'B_Catchall_Phrase', '', 'o', ''],
#  ['o', 'o', 'B_Feature/Action', 'o', 'I_Time', 'o', '', 'o'],
#  ['B_Feature/Action',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'I_Feature/Action',
#   'o',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'o',
#   'B_Catchall_Phrase',
#   'o',
#   'o'],
#  ['', 'o', 'o', '', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o'],
#  ['B_Number_Type',
#   'B_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   ''],
#  ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'B_Feature/Action', 'o', 'o'],
#  ['B_Feature/Action', 'B_Catchall_Phrase', 'o', 'o'],
#  ['B_Day', 'o', 'o', 'o', 'o'],
#  ['B_Feature/Action', 'o', 'I_Catchall_Phrase', 'o'],
#  ['B_Feature/Action', 'I_Feature/Action', '', 'o', 'o', 'o'],
#  ['o', 'I_Time', 'I_Time', '', 'I_Time', 'o', 'o', 'o'],
#  ['o', 'B_Feature/Action', 'o', 'o', 'o'],
#  ['o', 'o', 'B_Feature/Action'],
#  ['o',
#   'o',
#   'B_Feature/Action',
#   'B_Contact_Name',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o', 'B_Time', 'o', 'B_Feature/Action', 'o', 'o', 'o'],
#  ['o', 'B_Feature/Action', 'o', 'o'],
#  ['I_Time', 'I_Catchall_Phrase', 'o', 'o'],
#  ['I_Catchall_Phrase',
#   'o',
#   'I_Time',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase',
#   'I_Catchall_Phrase'],
#  ['I_Catchall_Phrase', 'o', 'I_Catchall_Phrase', 'I_Catchall_Phrase'],
#  ['o', 'o', 'o', 'o'],
#  ['I_Catchall_Phrase', 'I_Catchall_Phrase', 'I_Time', 'I_Time', 'o', 'o', 'o'],
#  ['o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', '', 'o', 'o', 'o', 'o', 'B_Number_Type', 'o', 'o'],
#  ['o', 'o'],
#  ['o', '', 'B_Recurrance', 'o', 'o', 'o', '', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'B_Feature/Action', 'o', 'o'],
#  ['o', '', '', 'o', 'o', 'o', 'B_Contact_Name', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Relation', 'I_Relation', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o'],
#  ['', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'B_Feature/Action', 'I_Feature/Action', 'o', 'o', 'o', 'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'B_Catchall_Phrase', 'o', 'o', 'o'],
#  ['o',
#   'o',
#   'o',
#   '',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'B_Location',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', '', 'o', 'o', '', 'o', 'o', '', 'o', 'o'],
#  ['o', 'B_Feature/Action', 'I_Feature/Action', 'o', 'o', 'o'],
#  ['B_App_Name', '', 'o', 'o', 'o', 'o', 'o', 'B_Relation'],
#  ['B_Catchall_Phrase', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['B_Feature/Action',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   '',
#   'I_Catchall_Phrase',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o',
#   'o'],
#  ['B_Relation', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  ['o', 'B_Relation', 'B_Date', 'o', 'o', 'o', 'o', '', 'o', 'o', 'o']]

# %%
import csv
with open('/content/drive/MyDrive/models/prometeo/test_public_res.csv', 'w', newline='') as file:
  writer = csv.writer(file)
  writer.writerow(['id', 'Predicted'])
  count = 0
  for val in result:
    for v in val:
      writer.writerow([count, v])
      count += 1
